# %% [markdown]
# # Maternal Health Risk Analysis and Classification

# %% [markdown]
# # 1. Problem Identification

# %% [markdown]
# Many pregnant women die from complications of pregnancy because of not having enough information about maternal health care during pregnancy and post-pregnancy. Every moment should be monitored during pregnancy for the healthy development of fetal and for making sure of the harmless delivery. Proper care and diagnosis at the beginning of pregnancy can help to reduce the preventable death of pregnant women and neonatal especially in rural areas
#
# In this notebook, we will analyze several attributes that affect the health of pregnant women. We will also create a machine learning model to predict the level of health risk for pregnant women.

# %% [markdown]
# # 2. Importing Packages and Dataset

# %% [markdown]
# ## 2.1 Importing Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split as split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# ## 2.2 Importing Dataset

# %%
data = pd.read_csv(r'C:\Users\manis\Downloads\ml_project\Maternal Health Risk Data Set.csv')
data.head()
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk

# %% [markdown]
# # 3. Variable Description and Identification

# %% [markdown]
# Let's check our dataset information first.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          1014 non-null   int64
#  1   SystolicBP   1014 non-null   int64
#  2   DiastolicBP  1014 non-null   int64
#  3   BS           1014 non-null   float64
#  4   BodyTemp     1014 non-null   float64
#  5   HeartRate    1014 non-null   int64
#  6   RiskLevel    1014 non-null   object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 55.6+ KB

# %% [markdown]
# ## 3.1 Variable Description

# %% [markdown]
# We can see total 6 variables, and each variables has 1014 observations. **Here comes the description of all variables:**<br/>
#    1. **Age**: Any ages in years when a women during pregnant.
#    2. **SystolicBP**: Upper value of Blood Pressure in mmHg.
#    3. **DiastolicBP**: Lower value of Blood Pressure in mmHg,
#    4. **BS**: Blood glucose levels is in terms of a molar concentration, mmol/L.
#    5. **BodyTemp**: Women body temperature.
#    5. **HeartRate**: A normal resting heart rate in beats per minute.
#    6. **Risk Level**: Predicted Risk Intensity Level during pregnancy considering the previous attribute.
#
# Here, we have Risk Level as target variable, and the rest of the variables are predictor variables.

# %% [markdown]
# ## 3.2 Variable Data Types

# %% [markdown]
# **Categorical Variable**: Risk Level.
#
# **Numerical Variable**: Age, SystolicBP, DiastolicBP, BS, BodyTemp, HeartRate.

# %% [markdown]
# ## 3.3 Checking Null/Missing Values

# %%
data.isnull().sum()
# Out:
# Age            0
# SystolicBP     0
# DiastolicBP    0
# BS             0
# BodyTemp       0
# HeartRate      0
# RiskLevel      0
# dtype: int64

# %% [markdown]
# Looks like there's no null/missing values in this dataset. We can move on to the next step.

# %% [markdown]
# ## 3.4 Checking Duplicates

# %% [markdown]
# Duplication just means that you have repeated data in your dataset. This could be due to things like data entry errors or data collection methods.

# %%
print(f"There are {data.duplicated().sum()} duplicates data")
data.loc[data.duplicated(keep=False)].sort_values(by=data.columns.to_list())
# Out:
# There are 562 duplicates data
#      Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 670   10         100           50   6.0      99.0         70   mid risk
# 849   10         100           50   6.0      99.0         70   mid risk
# 552   12          90           60   7.5     102.0         60   low risk
# 940   12          90           60   7.5     102.0         60   low risk
# 543   12          90           60   7.5     102.0         66   low risk
# ..   ...         ...          ...   ...       ...        ...        ...
# 553   60         120           85  15.0      98.0         60   mid risk
# 772   60         120           85  15.0      98.0         60   mid risk
# 818   60         120           85  15.0      98.0         60   mid risk
# 114   63         140           90  15.0      98.0         90  high risk
# 502   63         140           90  15.0      98.0         90  high risk
#
# [866 rows x 7 columns]

# %% [markdown]
# Wow, 562 duplicates data. That's very big number. **What should we do now?**<br/>
# Duplicate data takes up unnecessary storage space and slows down calculations at a minimum. At worst, duplicate data can skew analysis results and threaten the integrity of the data set. Including them will essentially lead to the model overfitting this subset of points. But in this case, we will try to analyze this data first to understand the distribution of the data.

# %% [markdown]
# # 4. Univariate Analysis

# %% [markdown]
# Univariate analysis separately explores the distribution of each variable in a data set. It looks at the range of values, as well as the central tendency of the values. Univariate data analysis does not look at relationships between various variables (like bivariate and multivariate analysis) rather it summarises each variable on its own.<br/><br/>
# Methods to perform univariate analysis will depend on whether the variable is categorical or numerical. For numerical variable, we would explore its shape of distribution (distribution can either be symmetric or skewed) using histogram and density plots. For categorical variables, we would use bar plots to visualize the absolute and proportional frequency distribution.

# %% [markdown]
# ## 4.1 Categorical Variables

# %% [markdown]
# For categorical variables, we'll just checking the frequency distribution of the data using bar plot. Another way to show the relationships between classes or categories of a variable is in a pie or circle chart. In a pie chart, each "slice" represents the proportion of the total phenomenon that is due to each of the classes or groups.

# %% [markdown]
# ### 4.1.1 Risk Level

# %%
p_colors = ['green', 'orange', 'red']
risk_order = ["low risk", "mid risk", "high risk"]
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

data["RiskLevel"].value_counts().plot(kind="pie", labels=risk_order, colors=p_colors, explode=[0.05, 0.05,  0.05], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title("Risk Level Pie Chart")
ax[0].set_ylabel('')

count = sns.countplot(x="RiskLevel", data=data, ax=ax[1], order=risk_order, palette=p_colors)
for bar in count.patches:
    count.annotate(format(bar.get_height()),
        (bar.get_x() + bar.get_width() / 2,
        bar.get_height()), ha='center', va='center',
        size=11, xytext=(0, 8),
        textcoords='offset points')
ax[1].set_title("Risk Level Bar Chart")
plt.show()
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_25284\2935681441.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   count = sns.countplot(x="RiskLevel", data=data, ax=ax[1], order=risk_order, palette=p_colors)

# %% [markdown]
# Looks like most pregnant weomen in this dataset mostly has low health risk. Out of 1014 observations, 406 (40%) of pregnant women has low risk, 336 (33.1%) has med risk, and 272 (26.8%) has high risk. We will explore the data to get more insights and see why pregnant women has different health risk. We will try to check each variable that can affect it. Let's explore it one by one.

# %% [markdown]
# ## 4.2 Numerical Variables

# %% [markdown]
# It's different from categorical variables which only has a few values that represent different classes/categories, numerical variables has a continuous value. Therefore to understand the distribution of data on each variable, we'll use **histogram** instead of bar chart.  A histogram is a chart that is similar to a bar chart, but it is used for interval and ratio level variables.
#
# Another thing to pay attention to in numerical data is outliers. An outlier is an observation that lies an abnormal distance from other values in a random sample from a population. If the outliers are non-randomly distributed, they can decrease normality (making the graph skewed). It increases the error variance and reduces the power of statistical tests. They can cause bias and/or influence estimates. We will use **box plot** to visualize continous data to find out whether there are outliers or not.
#
# But before that, we can use *desctibe()* function from pandas to display descriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset’s distribution, for early observation.

# %%
data.describe().T
# Out:
#               count        mean        std   min    25%    50%    75%    max
# Age          1014.0   29.871795  13.474386  10.0   19.0   26.0   39.0   70.0
# SystolicBP   1014.0  113.198225  18.403913  70.0  100.0  120.0  120.0  160.0
# DiastolicBP  1014.0   76.460552  13.885796  49.0   65.0   80.0   90.0  100.0
# BS           1014.0    8.725986   3.293532   6.0    6.9    7.5    8.0   19.0
# BodyTemp     1014.0   98.665089   1.371384  98.0   98.0   98.0   98.0  103.0
# HeartRate    1014.0   74.301775   8.088702   7.0   70.0   76.0   80.0   90.0

# %% [markdown]
# As we can see, looks like **Age**, **BS**, and **HeartRate** variable has outlier in it. But this is just preliminary guess. Let's explore the data deeper.

# %%
def num_plot(data, col):
    fig, ax = plt.subplots(1, 2, figsize=(12, 4))

    sns.histplot(data=data, x=col, kde=True, ax=ax[0])
    sns.boxplot(data=data, x=col, ax=ax[1])
    ax[0].set_title(f"{col} Distribution Histogram")
    ax[1].set_title(f"{col} Distribution Boxplot")

    plt.show()

# %% [markdown]
# ### 4.2.1 Age

# %%
num_plot(data, "Age")

# %% [markdown]
# ### 4.2.2 SystolicBP

# %%
num_plot(data, "SystolicBP")

# %% [markdown]
# ### 4.2.3 DiastolicBP

# %%
num_plot(data, "DiastolicBP")

# %% [markdown]
# ### 4.2.4 BS

# %%
num_plot(data, "BS")

# %% [markdown]
# ### 4.2.5 BodyTemp

# %%
num_plot(data, "BodyTemp")

# %% [markdown]
# ### 4.2.6 HeartRate

# %%
num_plot(data, "HeartRate")

# %% [markdown]
# **Observation:**
# Apparently, almost all variables has outlier that cause skewed distribution. For now, we will just ignore that outlier because that value seems to be a natural thing in this case, except for **HeartRate**. That variable has an outlier with a value that is too far from the other values.

# %% [markdown]
# # 5. Bivariate Analysis

# %% [markdown]
# Bivariate analysis lets you study the relationship that exists between two variables. It helps to find out if there is an association between the variables and if yes then what is the strength of association. One variable here is dependent while the other is independent. We can use correlation coefficients to find out how high is the relationship between two variables. We can also use scatter plot to show the patterns that can be formed using the two variables

# %% [markdown]
# ## 5.1 Numerical Variables

# %%
sns.heatmap(data.drop("RiskLevel", axis=1).corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Since we only have 6 numerical variables, we'll just use pairplot here. I think we can still see the graph clearly.

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# **Observation:** **SystolicBP** and **DiastolicBP** are highly correlated. As we can see from the graph, they have positive correlation with correlation coefficient value = 0.79. This means that SystolicBP and DiastolicBP variable contains highly similar information and there is very little or no variance in information. This is known as a problem called **MultiColinearity**, which undermines the statistical significance of an independent variable. We can remove one of them because we don't want a **redundant** variable while making or training our model. But we will try to dig deeper to decide whether we need to remove these variable, and which variable we should remove

# %% [markdown]
# ## 5.2 Predictor and Target

# %% [markdown]
# We will use histogram with hue mapping to visualize the predictor variables data distribution based on the target variable. Also, since our predictor variable only has few unique values, we can also use pandas crosstab to see the detailed values.

# %% [markdown]
# ### 5.2.1 Age → RiskLevel

# %%
sns.histplot(data=data, x="Age", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(data.RiskLevel, data.Age).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_43b56_row0_col0, #T_43b56_row0_col1, #T_43b56_row0_col4, #T_43b56_row0_col5, #T_43b56_row0_col7, #T_43b56_row0_col8, #T_43b56_row0_col9, #T_43b56_row0_col10, #T_43b56_row0_col11, #T_43b56_row0_col12, #T_43b56_row0_col13, #T_43b56_row0_col15, #T_43b56_row0_col16, #T_43b56_row0_col17, #T_43b56_row0_col20, #T_43b56_row0_col30, #T_43b56_row0_col31, #T_43b56_row0_col33, #T_43b56_row0_col37, #T_43b56_row0_col39, #T_43b56_row0_col43, #T_43b56_row0_col44, #T_43b56_row0_col45, #T_43b56_row0_col48, #T_43b56_row0_col49, #T_43b56_row1_col2, #T_43b56_row1_col3, #T_43b56_row1_col6, #T_43b56_row1_col15, #T_43b56_row1_col18, #T_43b56_row1_col19, #T_43b56_row1_col22, #T_43b56_row1_col25, #T_43b56_row1_col26, #T_43b56_row1_col27, #T_43b56_row1_col28, #T_43b56_row1_col29, #T_43b56_row1_col32, #T_43b56_row1_col33, #T_43b56_row1_col35, #T_43b56_row1_col36, #T_43b56_row1_col38, #T_43b56_row1_col40, #T_43b56_row1_col42, #T_43b56_row1_col46, #T_43b56_row2_col3, #T_43b56_row2_col13, #T_43b56_row2_col14, #T_43b56_row2_col16, #T_43b56_row2_col21, #T_43b56_row2_col23, #T_43b56_row2_col24, #T_43b56_row2_col26, #T_43b56_row2_col27, #T_43b56_row2_col30, #T_43b56_row2_col31, #T_43b56_row2_col34, #T_43b56_row2_col35, #T_43b56_row2_col37, #T_43b56_row2_col39, #T_43b56_row2_col41, #T_43b56_row2_col42, #T_43b56_row2_col43, #T_43b56_row2_col45, #T_43b56_row2_col46, #T_43b56_row2_col47, #T_43b56_row2_col48, #T_43b56_row2_col49 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_43b56_row0_col2 {
#   background-color: #cce666;
#   color: #000000;
# }
# #T_43b56_row0_col3, #T_43b56_row0_col6, #T_43b56_row0_col14, #T_43b56_row0_col21, #T_43b56_row0_col23, #T_43b56_row0_col24, #T_43b56_row0_col25, #T_43b56_row0_col26, #T_43b56_row0_col27, #T_43b56_row0_col28, #T_43b56_row0_col29, #T_43b56_row0_col32, #T_43b56_row0_col35, #T_43b56_row0_col36, #T_43b56_row0_col38, #T_43b56_row0_col40, #T_43b56_row0_col41, #T_43b56_row0_col42, #T_43b56_row0_col46, #T_43b56_row1_col0, #T_43b56_row1_col1, #T_43b56_row1_col4, #T_43b56_row1_col5, #T_43b56_row1_col9, #T_43b56_row1_col10, #T_43b56_row1_col11, #T_43b56_row1_col12, #T_43b56_row1_col13, #T_43b56_row1_col16, #T_43b56_row1_col21, #T_43b56_row1_col30, #T_43b56_row1_col31, #T_43b56_row1_col34, #T_43b56_row1_col37, #T_43b56_row1_col39, #T_43b56_row1_col43, #T_43b56_row1_col45, #T_43b56_row1_col47, #T_43b56_row1_col48, #T_43b56_row1_col49, #T_43b56_row2_col0, #T_43b56_row2_col2, #T_43b56_row2_col7, #T_43b56_row2_col8, #T_43b56_row2_col9, #T_43b56_row2_col15, #T_43b56_row2_col17, #T_43b56_row2_col18, #T_43b56_row2_col19, #T_43b56_row2_col20, #T_43b56_row2_col22, #T_43b56_row2_col25, #T_43b56_row2_col28, #T_43b56_row2_col33, #T_43b56_row2_col44 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_43b56_row0_col18 {
#   background-color: #c9e466;
#   color: #000000;
# }
# #T_43b56_row0_col19, #T_43b56_row0_col47, #T_43b56_row1_col14, #T_43b56_row2_col6 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_43b56_row0_col22, #T_43b56_row1_col23, #T_43b56_row2_col32 {
#   background-color: #55aa66;
#   color: #f1f1f1;
# }
# #T_43b56_row0_col34 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_43b56_row1_col7 {
#   background-color: #45a266;
#   color: #f1f1f1;
# }
# #T_43b56_row1_col8 {
#   background-color: #41a066;
#   color: #f1f1f1;
# }
# #T_43b56_row1_col17 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_43b56_row1_col20 {
#   background-color: #88c366;
#   color: #000000;
# }
# #T_43b56_row1_col24 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_43b56_row1_col41 {
#   background-color: #8ec666;
#   color: #000000;
# }
# #T_43b56_row1_col44 {
#   background-color: #249266;
#   color: #f1f1f1;
# }
# #T_43b56_row2_col1 {
#   background-color: #3f9f66;
#   color: #f1f1f1;
# }
# #T_43b56_row2_col4 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_43b56_row2_col5 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_43b56_row2_col10 {
#   background-color: #97cb66;
#   color: #000000;
# }
# #T_43b56_row2_col11 {
#   background-color: #b2d866;
#   color: #000000;
# }
# #T_43b56_row2_col12 {
#   background-color: #7cbe66;
#   color: #000000;
# }
# #T_43b56_row2_col29 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_43b56_row2_col36 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_43b56_row2_col38 {
#   background-color: #5aac66;
#   color: #f1f1f1;
# }
# #T_43b56_row2_col40 {
#   background-color: #aad466;
#   color: #000000;
# }
# </style>
# <table id="T_43b56">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Age</th>
#       <th id="T_43b56_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_43b56_level0_col1" class="col_heading level0 col1" >12</th>
#       <th id="T_43b56_level0_col2" class="col_heading level0 col2" >13</th>
#       <th id="T_43b56_level0_col3" class="col_heading level0 col3" >14</th>
#       <th id="T_43b56_level0_col4" class="col_heading level0 col4" >15</th>
#       <th id="T_43b56_level0_col5" class="col_heading level0 col5" >16</th>
#       <th id="T_43b56_level0_col6" class="col_heading level0 col6" >17</th>
#       <th id="T_43b56_level0_col7" class="col_heading level0 col7" >18</th>
#       <th id="T_43b56_level0_col8" class="col_heading level0 col8" >19</th>
#       <th id="T_43b56_level0_col9" class="col_heading level0 col9" >20</th>
#       <th id="T_43b56_level0_col10" class="col_heading level0 col10" >21</th>
#       <th id="T_43b56_level0_col11" class="col_heading level0 col11" >22</th>
#       <th id="T_43b56_level0_col12" class="col_heading level0 col12" >23</th>
#       <th id="T_43b56_level0_col13" class="col_heading level0 col13" >24</th>
#       <th id="T_43b56_level0_col14" class="col_heading level0 col14" >25</th>
#       <th id="T_43b56_level0_col15" class="col_heading level0 col15" >26</th>
#       <th id="T_43b56_level0_col16" class="col_heading level0 col16" >27</th>
#       <th id="T_43b56_level0_col17" class="col_heading level0 col17" >28</th>
#       <th id="T_43b56_level0_col18" class="col_heading level0 col18" >29</th>
#       <th id="T_43b56_level0_col19" class="col_heading level0 col19" >30</th>
#       <th id="T_43b56_level0_col20" class="col_heading level0 col20" >31</th>
#       <th id="T_43b56_level0_col21" class="col_heading level0 col21" >32</th>
#       <th id="T_43b56_level0_col22" class="col_heading level0 col22" >33</th>
#       <th id="T_43b56_level0_col23" class="col_heading level0 col23" >34</th>
#       <th id="T_43b56_level0_col24" class="col_heading level0 col24" >35</th>
#       <th id="T_43b56_level0_col25" class="col_heading level0 col25" >36</th>
#       <th id="T_43b56_level0_col26" class="col_heading level0 col26" >37</th>
#       <th id="T_43b56_level0_col27" class="col_heading level0 col27" >38</th>
#       <th id="T_43b56_level0_col28" class="col_heading level0 col28" >39</th>
#       <th id="T_43b56_level0_col29" class="col_heading level0 col29" >40</th>
#       <th id="T_43b56_level0_col30" class="col_heading level0 col30" >41</th>
#       <th id="T_43b56_level0_col31" class="col_heading level0 col31" >42</th>
#       <th id="T_43b56_level0_col32" class="col_heading level0 col32" >43</th>
#       <th id="T_43b56_level0_col33" class="col_heading level0 col33" >44</th>
#       <th id="T_43b56_level0_col34" class="col_heading level0 col34" >45</th>
#       <th id="T_43b56_level0_col35" class="col_heading level0 col35" >46</th>
#       <th id="T_43b56_level0_col36" class="col_heading level0 col36" >48</th>
#       <th id="T_43b56_level0_col37" class="col_heading level0 col37" >49</th>
#       <th id="T_43b56_level0_col38" class="col_heading level0 col38" >50</th>
#       <th id="T_43b56_level0_col39" class="col_heading level0 col39" >51</th>
#       <th id="T_43b56_level0_col40" class="col_heading level0 col40" >54</th>
#       <th id="T_43b56_level0_col41" class="col_heading level0 col41" >55</th>
#       <th id="T_43b56_level0_col42" class="col_heading level0 col42" >56</th>
#       <th id="T_43b56_level0_col43" class="col_heading level0 col43" >59</th>
#       <th id="T_43b56_level0_col44" class="col_heading level0 col44" >60</th>
#       <th id="T_43b56_level0_col45" class="col_heading level0 col45" >6

# %% [markdown]
# **Observation:**
# 1. Pregnant women aged below 24 years mostly has low health risk.
# 2. Health risks will start to increase after that age (starting from the age of 25 years).
# 3. Surprisingly, the health risk of pregnant women over 59 years old is decreased

# %% [markdown]
# ### 5.2.2 SystolicBP → RiskLevel

# %%
sns.histplot(data=data, x="SystolicBP", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(data.RiskLevel, data.SystolicBP).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_95795_row0_col0, #T_95795_row0_col1, #T_95795_row0_col2, #T_95795_row0_col3, #T_95795_row0_col4, #T_95795_row0_col7, #T_95795_row0_col8, #T_95795_row0_col9, #T_95795_row0_col10, #T_95795_row0_col12, #T_95795_row0_col13, #T_95795_row0_col14, #T_95795_row1_col5, #T_95795_row1_col6, #T_95795_row1_col11, #T_95795_row1_col12, #T_95795_row1_col15, #T_95795_row1_col16, #T_95795_row1_col17, #T_95795_row1_col18, #T_95795_row2_col1, #T_95795_row2_col2, #T_95795_row2_col3, #T_95795_row2_col4, #T_95795_row2_col5, #T_95795_row2_col9, #T_95795_row2_col14, #T_95795_row2_col16, #T_95795_row2_col18 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_95795_row0_col5, #T_95795_row0_col16, #T_95795_row0_col17, #T_95795_row0_col18, #T_95795_row1_col0, #T_95795_row1_col1, #T_95795_row1_col2, #T_95795_row1_col3, #T_95795_row1_col4, #T_95795_row1_col7, #T_95795_row1_col8, #T_95795_row1_col9, #T_95795_row1_col10, #T_95795_row1_col13, #T_95795_row1_col14, #T_95795_row2_col6, #T_95795_row2_col11, #T_95795_row2_col12, #T_95795_row2_col15 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_95795_row0_col6, #T_95795_row0_col15 {
#   background-color: #bfdf66;
#   color: #000000;
# }
# #T_95795_row0_col11 {
#   background-color: #249266;
#   color: #f1f1f1;
# }
# #T_95795_row2_col0 {
#   background-color: #99cc66;
#   color: #000000;
# }
# #T_95795_row2_col7 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_95795_row2_col8 {
#   background-color: #b6db66;
#   color: #000000;
# }
# #T_95795_row2_col10 {
#   background-color: #b7db66;
#   color: #000000;
# }
# #T_95795_row2_col13 {
#   background-color: #44a266;
#   color: #f1f1f1;
# }
# #T_95795_row2_col17 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# </style>
# <table id="T_95795">
#   <thead>
#     <tr>
#       <th class="index_name level0" >SystolicBP</th>
#       <th id="T_95795_level0_col0" class="col_heading level0 col0" >70</th>
#       <th id="T_95795_level0_col1" class="col_heading level0 col1" >75</th>
#       <th id="T_95795_level0_col2" class="col_heading level0 col2" >76</th>
#       <th id="T_95795_level0_col3" class="col_heading level0 col3" >78</th>
#       <th id="T_95795_level0_col4" class="col_heading level0 col4" >80</th>
#       <th id="T_95795_level0_col5" class="col_heading level0 col5" >83</th>
#       <th id="T_95795_level0_col6" class="col_heading level0 col6" >85</th>
#       <th id="T_95795_level0_col7" class="col_heading level0 col7" >90</th>
#       <th id="T_95795_level0_col8" class="col_heading level0 col8" >95</th>
#       <th id="T_95795_level0_col9" class="col_heading level0 col9" >99</th>
#       <th id="T_95795_level0_col10" class="col_heading level0 col10" >100</th>
#       <th id="T_95795_level0_col11" class="col_heading level0 col11" >110</th>
#       <th id="T_95795_level0_col12" class="col_heading level0 col12" >115</th>
#       <th id="T_95795_level0_col13" class="col_heading level0 col13" >120</th>
#       <th id="T_95795_level0_col14" class="col_heading level0 col14" >129</th>
#       <th id="T_95795_level0_col15" class="col_heading level0 col15" >130</th>
#       <th id="T_95795_level0_col16" class="col_heading level0 col16" >135</th>
#       <th id="T_95795_level0_col17" class="col_heading level0 col17" >140</th>
#       <th id="T_95795_level0_col18" class="col_heading level0 col18" >160</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95795_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_95795_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_95795_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_95795_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_95795_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_95795_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_95795_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_95795_row0_col6" class="data row0 col6" >13</td>
#       <td id="T_95795_row0_col7" class="data row0 col7" >33</td>
#       <td id="T_95795_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_95795_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_95795_row0_col10" class="data row0 col10" >5</td>
#       <td id="T_95795_row0_col11" class="data row0 col11" >8</td>
#       <td id="T_95795_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_95795_row0_col13" class="data row0 col13" >70</td>
#       <td id="T_95795_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_95795_row0_col15" class="data row0 col15" >12</td>
#       <td id="T_95795_row0_col16" class="data row0 col16" >3</td>
#       <td id="T_95795_row0_col17" class="data row0 col17" >115</td>
#       <td id="T_95795_row0_col18" class="data row0 col18" >10</td>
#     </tr>
#     <tr>
#       <th id="T_95795_level0_row1" class="row_heading level0 row1" >low risk</th>
#       <td id="T_95795_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_95795_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_95795_row1_col2" class="data row1 col2" >16</td>
#       <td id="T_95795_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_95795_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_95795_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_95795_row1_col6" class="data row1 col6" >11</td>
#       <td id="T_95795_row1_col7" class="data row1 col7" >72</td>
#       <td id="T_95795_row1_col8" class="data row1 col8" >8</td>
#       <td id="T_95795_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_95795_row1_col10" class="data row1 col10" >65</td>
#       <td id="T_95795_row1_col11" class="data row1 col11" >2</td>
#       <td id="T_95795_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_95795_row1_col13" class="data row1 col13" >208</td>
#       <td id="T_95795_row1_col14" class="data row1 col14" >1</td>
#       <td id="T_95795_row1_col15" class="data row1 col15" >0</td>
#       <td id="T_95795_row1_col16" class="data row1 col16" >0</td>
#       <td id="T_95795_row1_col17" class="data row1 col17" >0</td>
#       <td id="T_95795_row1_col18" class="data row1 col18" >0</td>
#     </tr>
#     <tr>
#       <th id="T_95795_level0_row2" class="row_heading level0 row2" >mid risk</th>
#       <td id="T_95795_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_95795_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_95795_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_95795_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_95795_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_95795_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_95795_row2_col6" class="data row2 col6" >19</td>
#       <td id="T_95795_row2_col7" class="data row2 col7" >49</td>
#       <td id="T_95795_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_95795_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_95795_row2_col10" class="data row2 col10" >22</td>
#       <td id="T_95795_row2_col11" class="data row2 col11" >9</td>
#       <td id="T_95795_row2_col12" class="data row2 col12" >8</td>
#       <td id="T_95795_row2_col13" class="data row2 col13" >171</td>
#       <td id="T_95795_row2_col14" class="data row2 col14" >0</td>
#       <td id="T_95795_row2_col15" class="data row2 col15" >48</td>
#       <td

# %% [markdown]
# **Observation:**
# 1. Pregnant women with upper value of blood pressure >= 100 mmHg mostly has low health risk.
# 2. The higher pregnant women's blood pressure, the higher the health risk

# %% [markdown]
# ### 5.2.3 DiastolicBP → RiskLevel

# %%
sns.histplot(data=data, x="DiastolicBP", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(data.RiskLevel, data.DiastolicBP).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_d1593_row0_col0, #T_d1593_row0_col1, #T_d1593_row0_col2, #T_d1593_row0_col3, #T_d1593_row0_col4, #T_d1593_row0_col5, #T_d1593_row0_col7, #T_d1593_row0_col9, #T_d1593_row0_col10, #T_d1593_row0_col11, #T_d1593_row0_col12, #T_d1593_row1_col3, #T_d1593_row1_col6, #T_d1593_row1_col15, #T_d1593_row2_col0, #T_d1593_row2_col5, #T_d1593_row2_col6, #T_d1593_row2_col8, #T_d1593_row2_col9, #T_d1593_row2_col12, #T_d1593_row2_col13, #T_d1593_row2_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d1593_row0_col6, #T_d1593_row0_col14, #T_d1593_row0_col15, #T_d1593_row1_col0, #T_d1593_row1_col1, #T_d1593_row1_col2, #T_d1593_row1_col4, #T_d1593_row1_col5, #T_d1593_row1_col8, #T_d1593_row1_col9, #T_d1593_row1_col10, #T_d1593_row1_col11, #T_d1593_row1_col12, #T_d1593_row1_col13, #T_d1593_row2_col3, #T_d1593_row2_col7 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_d1593_row0_col8 {
#   background-color: #bfdf66;
#   color: #000000;
# }
# #T_d1593_row0_col13 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_d1593_row1_col7, #T_d1593_row2_col4 {
#   background-color: #55aa66;
#   color: #f1f1f1;
# }
# #T_d1593_row1_col14 {
#   background-color: #bcde66;
#   color: #000000;
# }
# #T_d1593_row2_col1 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_d1593_row2_col2 {
#   background-color: #3e9e66;
#   color: #f1f1f1;
# }
# #T_d1593_row2_col10 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_d1593_row2_col11 {
#   background-color: #a4d266;
#   color: #000000;
# }
# #T_d1593_row2_col15 {
#   background-color: #eff766;
#   color: #000000;
# }
# </style>
# <table id="T_d1593">
#   <thead>
#     <tr>
#       <th class="index_name level0" >DiastolicBP</th>
#       <th id="T_d1593_level0_col0" class="col_heading level0 col0" >49</th>
#       <th id="T_d1593_level0_col1" class="col_heading level0 col1" >50</th>
#       <th id="T_d1593_level0_col2" class="col_heading level0 col2" >60</th>
#       <th id="T_d1593_level0_col3" class="col_heading level0 col3" >63</th>
#       <th id="T_d1593_level0_col4" class="col_heading level0 col4" >65</th>
#       <th id="T_d1593_level0_col5" class="col_heading level0 col5" >68</th>
#       <th id="T_d1593_level0_col6" class="col_heading level0 col6" >69</th>
#       <th id="T_d1593_level0_col7" class="col_heading level0 col7" >70</th>
#       <th id="T_d1593_level0_col8" class="col_heading level0 col8" >75</th>
#       <th id="T_d1593_level0_col9" class="col_heading level0 col9" >76</th>
#       <th id="T_d1593_level0_col10" class="col_heading level0 col10" >80</th>
#       <th id="T_d1593_level0_col11" class="col_heading level0 col11" >85</th>
#       <th id="T_d1593_level0_col12" class="col_heading level0 col12" >89</th>
#       <th id="T_d1593_level0_col13" class="col_heading level0 col13" >90</th>
#       <th id="T_d1593_level0_col14" class="col_heading level0 col14" >95</th>
#       <th id="T_d1593_level0_col15" class="col_heading level0 col15" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1593_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_d1593_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d1593_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_d1593_row0_col2" class="data row0 col2" >34</td>
#       <td id="T_d1593_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_d1593_row0_col4" class="data row0 col4" >14</td>
#       <td id="T_d1593_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_d1593_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_d1593_row0_col7" class="data row0 col7" >10</td>
#       <td id="T_d1593_row0_col8" class="data row0 col8" >12</td>
#       <td id="T_d1593_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_d1593_row0_col10" class="data row0 col10" >38</td>
#       <td id="T_d1593_row0_col11" class="data row0 col11" >10</td>
#       <td id="T_d1593_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_d1593_row0_col13" class="data row0 col13" >48</td>
#       <td id="T_d1593_row0_col14" class="data row0 col14" >23</td>
#       <td id="T_d1593_row0_col15" class="data row0 col15" >80</td>
#     </tr>
#     <tr>
#       <th id="T_d1593_level0_row1" class="row_heading level0 row1" >low risk</th>
#       <td id="T_d1593_row1_col0" class="data row1 col0" >25</td>
#       <td id="T_d1593_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_d1593_row1_col2" class="data row1 col2" >75</td>
#       <td id="T_d1593_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_d1593_row1_col4" class="data row1 col4" >41</td>
#       <td id="T_d1593_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_d1593_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_d1593_row1_col7" class="data row1 col7" >38</td>
#       <td id="T_d1593_row1_col8" class="data row1 col8" >15</td>
#       <td id="T_d1593_row1_col9" class="data row1 col9" >3</td>
#       <td id="T_d1593_row1_col10" class="data row1 col10" >96</td>
#       <td id="T_d1593_row1_col11" class="data row1 col11" >24</td>
#       <td id="T_d1593_row1_col12" class="data row1 col12" >1</td>
#       <td id="T_d1593_row1_col13" class="data row1 col13" >58</td>
#       <td id="T_d1593_row1_col14" class="data row1 col14" >9</td>
#       <td id="T_d1593_row1_col15" class="data row1 col15" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d1593_level0_row2" class="row_heading level0 row2" >mid risk</th>
#       <td id="T_d1593_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_d1593_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_d1593_row2_col2" class="data row2 col2" >65</td>
#       <td id="T_d1593_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_d1593_row2_col4" class="data row2 col4" >32</td>
#       <td id="T_d1593_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_d1593_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_d1593_row2_col7" class="data row2 col7" >52</td>
#       <td id="T_d1593_row2_col8" class="data row2 col8" >11</td>
#       <td id="T_d1593_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_d1593_row2_col10" class="data row2 col10" >92</td>
#       <td id="T_d1593_row2_col11" class="data row2 col11" >15</td>
#       <td id="T_d1593_row2_col12" class="data row2 col12" >0</td>
#       <td id="T_d1593_row2_col13" class="data row2 col13" >47</td>
#       <td id="T_d1593_row2_col14" class="data row2 col14" >4</td>
#       <td id="T_d1593_row2_col15" class="data row2 col15" >6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Observation:**
# 1. This variable has pretty similar pattern as SystolicBP. This is not surprising since they're highly correlated.

# %% [markdown]
# ### 5.2.4 BS → RiskLevel

# %%
sns.histplot(data=data, x="BS", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(data.RiskLevel, data.BS).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_95c13_row0_col0, #T_95c13_row0_col1, #T_95c13_row0_col3, #T_95c13_row0_col4, #T_95c13_row0_col5, #T_95c13_row0_col6, #T_95c13_row0_col7, #T_95c13_row0_col8, #T_95c13_row0_col9, #T_95c13_row0_col11, #T_95c13_row0_col13, #T_95c13_row0_col14, #T_95c13_row0_col16, #T_95c13_row0_col17, #T_95c13_row1_col2, #T_95c13_row1_col10, #T_95c13_row1_col18, #T_95c13_row1_col19, #T_95c13_row1_col20, #T_95c13_row1_col21, #T_95c13_row1_col22, #T_95c13_row1_col23, #T_95c13_row1_col24, #T_95c13_row1_col25, #T_95c13_row1_col26, #T_95c13_row1_col27, #T_95c13_row1_col28, #T_95c13_row2_col2, #T_95c13_row2_col4, #T_95c13_row2_col5, #T_95c13_row2_col11, #T_95c13_row2_col12, #T_95c13_row2_col14, #T_95c13_row2_col15, #T_95c13_row2_col20, #T_95c13_row2_col23, #T_95c13_row2_col26, #T_95c13_row2_col28 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_95c13_row0_col2, #T_95c13_row0_col18, #T_95c13_row0_col20, #T_95c13_row0_col21, #T_95c13_row0_col22, #T_95c13_row0_col23, #T_95c13_row0_col24, #T_95c13_row0_col26, #T_95c13_row0_col27, #T_95c13_row0_col28, #T_95c13_row1_col1, #T_95c13_row1_col3, #T_95c13_row1_col4, #T_95c13_row1_col5, #T_95c13_row1_col11, #T_95c13_row1_col12, #T_95c13_row1_col13, #T_95c13_row1_col14, #T_95c13_row1_col15, #T_95c13_row1_col17, #T_95c13_row2_col0, #T_95c13_row2_col6, #T_95c13_row2_col7, #T_95c13_row2_col8, #T_95c13_row2_col9, #T_95c13_row2_col10, #T_95c13_row2_col16, #T_95c13_row2_col19, #T_95c13_row2_col25 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_95c13_row0_col10, #T_95c13_row1_col0, #T_95c13_row2_col22 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_95c13_row0_col12 {
#   background-color: #92c866;
#   color: #000000;
# }
# #T_95c13_row0_col15 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_95c13_row0_col19 {
#   background-color: #5eae66;
#   color: #f1f1f1;
# }
# #T_95c13_row0_col25 {
#   background-color: #1c8e66;
#   color: #f1f1f1;
# }
# #T_95c13_row1_col6 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_95c13_row1_col7 {
#   background-color: #219066;
#   color: #f1f1f1;
# }
# #T_95c13_row1_col8 {
#   background-color: #389c66;
#   color: #f1f1f1;
# }
# #T_95c13_row1_col9 {
#   background-color: #5faf66;
#   color: #f1f1f1;
# }
# #T_95c13_row1_col16 {
#   background-color: #1f8f66;
#   color: #f1f1f1;
# }
# #T_95c13_row2_col1 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_95c13_row2_col3, #T_95c13_row2_col18 {
#   background-color: #bfdf66;
#   color: #000000;
# }
# #T_95c13_row2_col13 {
#   background-color: #c9e466;
#   color: #000000;
# }
# #T_95c13_row2_col17 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_95c13_row2_col21 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_95c13_row2_col24 {
#   background-color: #e5f266;
#   color: #000000;
# }
# #T_95c13_row2_col27 {
#   background-color: #d7eb66;
#   color: #000000;
# }
# </style>
# <table id="T_95c13">
#   <thead>
#     <tr>
#       <th class="index_name level0" >BS</th>
#       <th id="T_95c13_level0_col0" class="col_heading level0 col0" >6.000000</th>
#       <th id="T_95c13_level0_col1" class="col_heading level0 col1" >6.100000</th>
#       <th id="T_95c13_level0_col2" class="col_heading level0 col2" >6.300000</th>
#       <th id="T_95c13_level0_col3" class="col_heading level0 col3" >6.400000</th>
#       <th id="T_95c13_level0_col4" class="col_heading level0 col4" >6.500000</th>
#       <th id="T_95c13_level0_col5" class="col_heading level0 col5" >6.600000</th>
#       <th id="T_95c13_level0_col6" class="col_heading level0 col6" >6.700000</th>
#       <th id="T_95c13_level0_col7" class="col_heading level0 col7" >6.800000</th>
#       <th id="T_95c13_level0_col8" class="col_heading level0 col8" >6.900000</th>
#       <th id="T_95c13_level0_col9" class="col_heading level0 col9" >7.000000</th>
#       <th id="T_95c13_level0_col10" class="col_heading level0 col10" >7.010000</th>
#       <th id="T_95c13_level0_col11" class="col_heading level0 col11" >7.100000</th>
#       <th id="T_95c13_level0_col12" class="col_heading level0 col12" >7.200000</th>
#       <th id="T_95c13_level0_col13" class="col_heading level0 col13" >7.500000</th>
#       <th id="T_95c13_level0_col14" class="col_heading level0 col14" >7.600000</th>
#       <th id="T_95c13_level0_col15" class="col_heading level0 col15" >7.700000</th>
#       <th id="T_95c13_level0_col16" class="col_heading level0 col16" >7.800000</th>
#       <th id="T_95c13_level0_col17" class="col_heading level0 col17" >7.900000</th>
#       <th id="T_95c13_level0_col18" class="col_heading level0 col18" >8.000000</th>
#       <th id="T_95c13_level0_col19" class="col_heading level0 col19" >9.000000</th>
#       <th id="T_95c13_level0_col20" class="col_heading level0 col20" >10.000000</th>
#       <th id="T_95c13_level0_col21" class="col_heading level0 col21" >11.000000</th>
#       <th id="T_95c13_level0_col22" class="col_heading level0 col22" >12.000000</th>
#       <th id="T_95c13_level0_col23" class="col_heading level0 col23" >13.000000</th>
#       <th id="T_95c13_level0_col24" class="col_heading level0 col24" >15.000000</th>
#       <th id="T_95c13_level0_col25" class="col_heading level0 col25" >16.000000</th>
#       <th id="T_95c13_level0_col26" class="col_heading level0 col26" >17.000000</th>
#       <th id="T_95c13_level0_col27" class="col_heading level0 col27" >18.000000</th>
#       <th id="T_95c13_level0_col28" class="col_heading level0 col28" >19.000000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95c13_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_95c13_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_95c13_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_95c13_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_95c13_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_95c13_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_95c13_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_95c13_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_95c13_row0_col7" class="data row0 col7" >10</td>
#       <td id="T_95c13_row0_col8" class="data row0 col8" >8</td>
#       <td id="T_95c13_row0_col9" class="data row0 col9" >9</td>
#       <td id="T_95c13_row0_col10" class="data row0 col10" >5</td>
#       <td id="T_95c13_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_95c13_row0_col12" class="data row0 col12" >6</td>
#       <td id="T_95c13_row0_col13" class="data row0 col13" >11</td>
#       <td id="T_95c13_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_95c13_row0_col15" class="data row0 col15" >4</td>
#       <td id="T_95c13_row0_col16" class="data row0 col16" >5</td>
#       <td id="T_95c13_row0_col17" class="data row0 col17" >12</td>
#       <td id="T_95c13_row0_col18" class="data row0 col18" >12</td>
#       <td id="T_95c13_row0_col19" class="

# %% [markdown]
# **Observation:**
# 1. Almost every pregnant women with blood glucose level >= 8 has high health risk.
# 2. But otherwise, they seems to have lower health risk with blood glucose < 8

# %% [markdown]
# ### 5.2.5 BodyTemp → RiskLevel

# %%
sns.histplot(data=data, x="BodyTemp", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(data.RiskLevel, data.BodyTemp).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_7444a_row0_col0, #T_7444a_row0_col1, #T_7444a_row0_col3, #T_7444a_row1_col2, #T_7444a_row1_col4, #T_7444a_row1_col5, #T_7444a_row1_col6, #T_7444a_row2_col1, #T_7444a_row2_col2, #T_7444a_row2_col3, #T_7444a_row2_col7 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_7444a_row0_col2, #T_7444a_row0_col6, #T_7444a_row0_col7, #T_7444a_row1_col0, #T_7444a_row1_col1, #T_7444a_row1_col3, #T_7444a_row2_col4, #T_7444a_row2_col5 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_7444a_row0_col4 {
#   background-color: #badc66;
#   color: #000000;
# }
# #T_7444a_row0_col5 {
#   background-color: #71b866;
#   color: #f1f1f1;
# }
# #T_7444a_row1_col7 {
#   background-color: #3f9f66;
#   color: #f1f1f1;
# }
# #T_7444a_row2_col0 {
#   background-color: #b4da66;
#   color: #000000;
# }
# #T_7444a_row2_col6 {
#   background-color: #49a466;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7444a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >BodyTemp</th>
#       <th id="T_7444a_level0_col0" class="col_heading level0 col0" >98.000000</th>
#       <th id="T_7444a_level0_col1" class="col_heading level0 col1" >98.400000</th>
#       <th id="T_7444a_level0_col2" class="col_heading level0 col2" >98.600000</th>
#       <th id="T_7444a_level0_col3" class="col_heading level0 col3" >99.000000</th>
#       <th id="T_7444a_level0_col4" class="col_heading level0 col4" >100.000000</th>
#       <th id="T_7444a_level0_col5" class="col_heading level0 col5" >101.000000</th>
#       <th id="T_7444a_level0_col6" class="col_heading level0 col6" >102.000000</th>
#       <th id="T_7444a_level0_col7" class="col_heading level0 col7" >103.000000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7444a_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_7444a_row0_col0" class="data row0 col0" >199</td>
#       <td id="T_7444a_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_7444a_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_7444a_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_7444a_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_7444a_row0_col5" class="data row0 col5" >34</td>
#       <td id="T_7444a_row0_col6" class="data row0 col6" >25</td>
#       <td id="T_7444a_row0_col7" class="data row0 col7" >6</td>
#     </tr>
#     <tr>
#       <th id="T_7444a_level0_row1" class="row_heading level0 row1" >low risk</th>
#       <td id="T_7444a_row1_col0" class="data row1 col0" >359</td>
#       <td id="T_7444a_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_7444a_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_7444a_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_7444a_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_7444a_row1_col5" class="data row1 col5" >14</td>
#       <td id="T_7444a_row1_col6" class="data row1 col6" >18</td>
#       <td id="T_7444a_row1_col7" class="data row1 col7" >5</td>
#     </tr>
#     <tr>
#       <th id="T_7444a_level0_row2" class="row_heading level0 row2" >mid risk</th>
#       <td id="T_7444a_row2_col0" class="data row2 col0" >246</td>
#       <td id="T_7444a_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_7444a_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_7444a_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_7444a_row2_col4" class="data row2 col4" >13</td>
#       <td id="T_7444a_row2_col5" class="data row2 col5" >50</td>
#       <td id="T_7444a_row2_col6" class="data row2 col6" >23</td>
#       <td id="T_7444a_row2_col7" class="data row2 col7" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Observation:**
# 1. Most pregnant women seem to have a body temperature of 98 F, which is normal body temperature
# 2. Pregnant women with body temperature >= 100 mostly has higher health risk

# %% [markdown]
# ### 5.2.6 HeartRate → RiskLevel

# %%
sns.histplot(data=data, x="HeartRate", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(data.RiskLevel, data.HeartRate).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_655a7_row0_col0, #T_655a7_row0_col1, #T_655a7_row0_col2, #T_655a7_row0_col5, #T_655a7_row0_col6, #T_655a7_row0_col7, #T_655a7_row0_col8, #T_655a7_row0_col12, #T_655a7_row1_col4, #T_655a7_row1_col5, #T_655a7_row1_col10, #T_655a7_row1_col13, #T_655a7_row1_col15, #T_655a7_row2_col0, #T_655a7_row2_col3, #T_655a7_row2_col7, #T_655a7_row2_col9, #T_655a7_row2_col11, #T_655a7_row2_col14, #T_655a7_row2_col15 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_655a7_row0_col3 {
#   background-color: #bbdd66;
#   color: #000000;
# }
# #T_655a7_row0_col4, #T_655a7_row0_col11, #T_655a7_row0_col14, #T_655a7_row0_col15, #T_655a7_row1_col0, #T_655a7_row1_col1, #T_655a7_row1_col3, #T_655a7_row1_col6, #T_655a7_row1_col7, #T_655a7_row1_col9, #T_655a7_row1_col12, #T_655a7_row2_col2, #T_655a7_row2_col4, #T_655a7_row2_col5, #T_655a7_row2_col8, #T_655a7_row2_col10, #T_655a7_row2_col13 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_655a7_row0_col9 {
#   background-color: #c1e066;
#   color: #000000;
# }
# #T_655a7_row0_col10 {
#   background-color: #c9e466;
#   color: #000000;
# }
# #T_655a7_row0_col13 {
#   background-color: #359a66;
#   color: #f1f1f1;
# }
# #T_655a7_row1_col2 {
#   background-color: #55aa66;
#   color: #f1f1f1;
# }
# #T_655a7_row1_col8 {
#   background-color: #078366;
#   color: #f1f1f1;
# }
# #T_655a7_row1_col11 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_655a7_row1_col14 {
#   background-color: #68b366;
#   color: #f1f1f1;
# }
# #T_655a7_row2_col1 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_655a7_row2_col6 {
#   background-color: #4aa466;
#   color: #f1f1f1;
# }
# #T_655a7_row2_col12 {
#   background-color: #198c66;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_655a7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >HeartRate</th>
#       <th id="T_655a7_level0_col0" class="col_heading level0 col0" >7</th>
#       <th id="T_655a7_level0_col1" class="col_heading level0 col1" >60</th>
#       <th id="T_655a7_level0_col2" class="col_heading level0 col2" >65</th>
#       <th id="T_655a7_level0_col3" class="col_heading level0 col3" >66</th>
#       <th id="T_655a7_level0_col4" class="col_heading level0 col4" >67</th>
#       <th id="T_655a7_level0_col5" class="col_heading level0 col5" >68</th>
#       <th id="T_655a7_level0_col6" class="col_heading level0 col6" >70</th>
#       <th id="T_655a7_level0_col7" class="col_heading level0 col7" >75</th>
#       <th id="T_655a7_level0_col8" class="col_heading level0 col8" >76</th>
#       <th id="T_655a7_level0_col9" class="col_heading level0 col9" >77</th>
#       <th id="T_655a7_level0_col10" class="col_heading level0 col10" >78</th>
#       <th id="T_655a7_level0_col11" class="col_heading level0 col11" >80</th>
#       <th id="T_655a7_level0_col12" class="col_heading level0 col12" >82</th>
#       <th id="T_655a7_level0_col13" class="col_heading level0 col13" >86</th>
#       <th id="T_655a7_level0_col14" class="col_heading level0 col14" >88</th>
#       <th id="T_655a7_level0_col15" class="col_heading level0 col15" >90</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_655a7_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_655a7_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_655a7_row0_col1" class="data row0 col1" >20</td>
#       <td id="T_655a7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_655a7_row0_col3" class="data row0 col3" >25</td>
#       <td id="T_655a7_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_655a7_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_655a7_row0_col6" class="data row0 col6" >43</td>
#       <td id="T_655a7_row0_col7" class="data row0 col7" >6</td>
#       <td id="T_655a7_row0_col8" class="data row0 col8" >20</td>
#       <td id="T_655a7_row0_col9" class="data row0 col9" >25</td>
#       <td id="T_655a7_row0_col10" class="data row0 col10" >9</td>
#       <td id="T_655a7_row0_col11" class="data row0 col11" >48</td>
#       <td id="T_655a7_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_655a7_row0_col13" class="data row0 col13" >22</td>
#       <td id="T_655a7_row0_col14" class="data row0 col14" >30</td>
#       <td id="T_655a7_row0_col15" class="data row0 col15" >19</td>
#     </tr>
#     <tr>
#       <th id="T_655a7_level0_row1" class="row_heading level0 row1" >low risk</th>
#       <td id="T_655a7_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_655a7_row1_col1" class="data row1 col1" >33</td>
#       <td id="T_655a7_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_655a7_row1_col3" class="data row1 col3" >44</td>
#       <td id="T_655a7_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_655a7_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_655a7_row1_col6" class="data row1 col6" >126</td>
#       <td id="T_655a7_row1_col7" class="data row1 col7" >7</td>
#       <td id="T_655a7_row1_col8" class="data row1 col8" >55</td>
#       <td id="T_655a7_row1_col9" class="data row1 col9" >56</td>
#       <td id="T_655a7_row1_col10" class="data row1 col10" >2</td>
#       <td id="T_655a7_row1_col11" class="data row1 col11" >39</td>
#       <td id="T_655a7_row1_col12" class="data row1 col12" >10</td>
#       <td id="T_655a7_row1_col13" class="data row1 col13" >7</td>
#       <td id="T_655a7_row1_col14" class="data row1 col14" >21</td>
#       <td id="T_655a7_row1_col15" class="data row1 col15" >0</td>
#     </tr>
#     <tr>
#       <th id="T_655a7_level0_row2" class="row_heading level0 row2" >mid risk</th>
#       <td id="T_655a7_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_655a7_row2_col1" class="data row2 col1" >21</td>
#       <td id="T_655a7_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_655a7_row2_col3" class="data row2 col3" >18</td>
#       <td id="T_655a7_row2_col4" class="data row2 col4" >5</td>
#       <td id="T_655a7_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_655a7_row2_col6" class="data row2 col6" >102</td>
#       <td id="T_655a7_row2_col7" class="data row2 col7" >6</td>
#       <td id="T_655a7_row2_col8" class="data row2 col8" >56</td>
#       <td id="T_655a7_row2_col9" class="data row2 col9" >15</td>
#       <td id="T_655a7_row2_col10" class="data row2 col10" >35</td>
#       <td id="T_655a7_row2_col11" class="data row2 col11" >30</td>
#       <td id="T_655a7_row2_col12" class="data row2 col12" >9</td>
#       <td id="T_655a7_row2_col13" class="data row2 col13" >26</td>
#       <td id="T_655a7_row2_col14" class="data row2 col14" >8</td>
#       <td id="T_655a7_row2_col15" class="data row2 col15" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Observation:**
# 1. As i mentioned before, HeartRate variable has outlier that with a value that looks unnatural, which is 6 bpm.
# 2. Health risks seem to be getting higher along with the number of heart rate.

# %% [markdown]
# # 6. Multivariate Analysis

# %% [markdown]
# Multivariate analysis involves analyzing multiple variables (more than two) to identify any possible association  and find the relationship among them. More specifically, we will try to associate more than one predictor variable with the response variable.
#
# In this case, we will just analyze the impact of 2 different predictor variables at a time on RiskLevel variable. We will use scatter plot since all of our predictor variables has numerical values, and then group them using RiskLevel values with different colors.

# %% [markdown]
# ## 6.1 Age and SystolicBP → RiskLevel

# %%
sns.scatterplot(data=data, x="Age", y="SystolicBP", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. Pregnant women with high SystolicBP seems to have a high health risk, regardless of their age.
# 2. Having low SystolicBP at a young age (under 50 years) doesn't guarantee does not guarantee our health risk is low, but it seems to have it in old age makes our health risks lower.

# %% [markdown]
# ## 6.2 Age and DiastolicBP → RiskLevel

# %%
sns.scatterplot(data=data, x="Age", y="DiastolicBP", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. We can see the same pattern as before, since SystolicBP and DiastolicBP are highly correlated

# %% [markdown]
# ## 6.3 Age and BS → RiskLevel

# %%
sns.scatterplot(data=data, x="Age", y="BS", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. Pregnant women with high blood glucose level seems to have a high health risk, regardless of their age.

# %% [markdown]
# ## 6.4 Age and BodyTemp → RiskLevel

# %%
sns.scatterplot(data=data, x="Age", y="BodyTemp", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. Younger women with normal body temperature mostly have low health risk, but they'll have higher risk if they have high body temperature.
# 2. High body temperature for older women doesn't doesn't appear to significantly affect their health risks

# %% [markdown]
# ## 6.5 Age and HeartRate → RiskLevel

# %%
sns.scatterplot(data=data, x="Age", y="HeartRate", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. It seems that heart rate has less effect on pregnant women's health risk compared to age

# %% [markdown]
# ## 6.6 SystolicBP and DiastolicBP → RiskLevel

# %%
sns.scatterplot(data=data, x="SystolicBP", y="DiastolicBP", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. Apparently, pregnant women with lower SystolicBP and DiastolicBP seems to have a lower health risk.
# 2. But otherwise, the higher SystolicBP and DiastolicBP they have, the higher their health risk.

# %% [markdown]
# ## 6.7 SystolicBP and BS → RiskLevel

# %%
sns.scatterplot(data=data, x="SystolicBP", y="BS", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. We can see almost similar pattern as before.
# 2. However, a higher BS value seems to affect the health risks of pregnant women more.

# %% [markdown]
# ## 6.8 SystolicBP and BodyTemp → RiskLevel

# %%
sns.scatterplot(data=data, x="SystolicBP", y="BodyTemp", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. Pregnant women with normal body temperature and low SystolicBP mostly has low health risk.
# 2. But the one who has high SystolicBP seems to have higher health risk, regardless of their body temperature.

# %% [markdown]
# ## 6.9 SystolicBP and HeartRate → RiskLevel

# %%
sns.scatterplot(data=data, x="SystolicBP", y="HeartRate", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. HeartRate value seems has less effect on pregnant women's health risk compared to SystolicBP.
# 2. Looks like HeartRate variabel isn't really useful.

# %% [markdown]
# ## 6.10 DiastolicBP and BS → RiskLevel

# %%
sns.scatterplot(data=data, x="DiastolicBP", y="BS", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. Pregnant women with high blood glucose level has higher health risk, regardless of their DiastolicBP.

# %% [markdown]
# ## 6.11 DiastolicBP and BodyTemp → RiskLevel

# %%
sns.scatterplot(data=data, x="DiastolicBP", y="BodyTemp", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. Pregnant women with low DiastolicBP and low body temperature mostly has low health risk, but their health risk will get higher if they have higher body temperature.

# %% [markdown]
# ## 6.12 DiastolicBP and HeartRate → RiskLevel

# %%
sns.scatterplot(data=data, x="DiastolicBP", y="HeartRate", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. Again, HeartRate value seems has less effect on pregnant women's health risk compared to DiastolicBP.
# 2. Looks like HeartRate variabel isn't really useful.

# %% [markdown]
# ## 6.13 BS and BodyTemp → RiskLevel

# %%
sns.scatterplot(data=data, x="BS", y="BodyTemp", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. Pregnant women with high blood glucose level seems to have a high health risk, regardless of their body temperature.

# %% [markdown]
# ## 6.14 BS and HeartRate → RiskLevel

# %%
sns.scatterplot(data=data, x="BS", y="HeartRate", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. Apparently, Pregnant women with higher blood glucose level seems to have a higher health risk, regardless of their heart rate.

# %% [markdown]
# ## 6.15 BodyTemp and HeartRate → RiskLevel

# %%
sns.scatterplot(data=data, x="BodyTemp", y="HeartRate", hue="RiskLevel", hue_order=risk_order, palette=p_colors)
plt.show()

# %% [markdown]
# **Observation:**
# 1. Pregnant women with higher body temperature seems to have a higher health risk, regardless of their heart rate (please note that according to previous analysis, pregnant women in this obervation mostly has 98 F body temperature).
# 2. HeartRate variable really isn't helpful in this case.

# %% [markdown]
# # 7. Feature Engineering and Data Cleaning

# %% [markdown]
# ## 7.1 Outlier Handling

# %% [markdown]
# As we know from the previous analysis, in this dataset there are several variables that have outliers, but even so most of those values still make sense in real life. The only variable that has an outlier with an unreasonable value is HeartRate. In this variable, there are two observations that have a heart rate value of 7 bpm (beats per minute). A normal resting heart rate for adults ranges from 60 to 100 beats per minute, and the lowest recorded resting heart rate in human history was 25 bpm. Therefore, we will drop this 2 records that has a heart rate value of 7 because that value doesn't make any sense, and most likely is an input error.
#
# We won't store processed data in the original variable, but instead we will store it in the new variable, so we can compare it with the original data.

# %%
data_proc = data.drop(data.index[data.HeartRate == 7])

fig, ax = plt.subplots(1, 2, figsize=(12, 4))
sns.histplot(data=data, x="HeartRate", kde=True, ax=ax[0])
sns.histplot(data=data_proc, x="HeartRate", kde=True, ax=ax[1])
ax[0].set_title("Original HeartRate Distribution")
ax[1].set_title("Processed HeartRate Distribution")
plt.show()

# %% [markdown]
# ## 7.2 Removing Irrelevant Features

# %% [markdown]
# After conducting several analyzes of the predictor variables, we conclude that the HeartRate variable is less helpful in determining the health risks of pregnant women. So, it's safe to remove that variable.

# %%
data_proc = data_proc.drop(["HeartRate"], axis=1)

# %% [markdown]
# You might think why we drop records that has outlier on HeartRate variable if we will delete that variable in the end. The answer is because it has input error in it, so that records maybe not legit. It could be that the label given is also not correct, so it will mislead the training process which makes the model becomes less accurate.

# %% [markdown]
# # 8. Model Building

# %% [markdown]
# ## 8.1 Splitting Dataset

# %% [markdown]
# We will split our dataset into 80% train data and 20% test data.

# %%
# Original Dataset
X = data.drop("RiskLevel", axis=1)
y = data.RiskLevel
x_train, x_test, y_train, y_test = split(X, y, test_size=0.2, random_state=1)

# Processed Dataset
X_proc = data_proc.drop("RiskLevel", axis=1)
y_proc = data_proc.RiskLevel
x_train_proc, x_test_proc, y_train_proc, y_test_proc = split(X_proc, y_proc, test_size=0.2, random_state=1)

print(f"Original data has {x_train.shape[0]} train data and {x_test.shape[0]} test data\n")
print(f"Processes data has {x_train_proc.shape[0]} train data and {x_test_proc.shape[0]} test data")
# Out:
# Original data has 811 train data and 203 test data
#
# Processes data has 809 train data and 203 test data

# %% [markdown]
# ## 8.2 Building Classification Model

# %% [markdown]
# In this case we will use Random Forest algorithm to build our model. Random forest contains many decision trees representing a distinct instance of the classification of data input. The random forest technique considers the instances individually, taking the one with the majority of votes as the selected prediction. In such a way, the random forest enables any classifiers with weak correlations to create a strong classifier.
#
# We choose Random Forest because it's one of the most accurate learning algorithms available, and it's training time is fast. Also, Random Forest can work on dataset that have feature values with different scales, so we don't need to do normalization/feature scaling.

# %%
# Using original dataset
rf = RandomForestClassifier(random_state=100)
rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)
print(f"Original Dataset Accuracy: {accuracy_score(y_test, y_pred)}")

# Using processed dataset
rf2 = RandomForestClassifier(random_state=100)
rf2.fit(x_train_proc, y_train_proc)
y_pred = rf2.predict(x_test_proc)
print(f"Processed Dataset Accuracy: {accuracy_score(y_test_proc, y_pred)}")
# Out:
# Original Dataset Accuracy: 0.8669950738916257
# Processed Dataset Accuracy: 0.8916256157635468

# %% [markdown]
# Here we go. We got 2.46% more test data accuracy with our processed dataset. It shows that our model has better generalization with our processed dataset to our test data. Not only that, Random Forest also has several hyperparameters that we can adjust to get a model with even better generalization.

# %% [markdown]
# ## 8.3 Hyperparameter Tuning

# %% [markdown]
# We will try to adjust 2 of Random Forest parameters, which is n_estimators and criterion. n_estimator is the number of trees in the forest, while criterion is the function to measure the quality of a split. To do that, we will use GridSearchCrossValidation with the number of folds as much as 10.

# %%
params = {
    "n_estimators": [10, 20, 50, 100],
    "criterion": ["gini", "entropy"]
}
rf = RandomForestClassifier(random_state=100)
grid = GridSearchCV(rf, params, cv=10)
grid.fit(x_train_proc, y_train_proc)
print("Best hyperparameter:", grid.best_params_)
# Out:
# Best hyperparameter: {'criterion': 'gini', 'n_estimators': 50}

# %%
pd.DataFrame(grid.cv_results_).sort_values(by="rank_test_score")[["params", "mean_test_score", "rank_test_score"]]
# Out:
#                                           params  mean_test_score  \
# 2      {'criterion': 'gini', 'n_estimators': 50}         0.831867
# 3     {'criterion': 'gini', 'n_estimators': 100}         0.830648
# 7  {'criterion': 'entropy', 'n_estimators': 100}         0.828179
# 6   {'criterion': 'entropy', 'n_estimators': 50}         0.828164
# 1      {'criterion': 'gini', 'n_estimators': 20}         0.823241
# 5   {'criterion': 'entropy', 'n_estimators': 20}         0.822006
# 4   {'criterion': 'entropy', 'n_estimators': 10}         0.818210
# 0      {'criterion': 'gini', 'n_estimators': 10}         0.808302
#
#    rank_test_score
# 2                1
# 3                2
# 7                3
# 6                4
# 1                5
# 5                6
# 4                7
# 0                8

# %%
y_pred = grid.predict(x_test_proc)
print(f"Processed Dataset Accuracy: {accuracy_score(y_test_proc, y_pred)}")
# Out:
# Processed Dataset Accuracy: 0.9014778325123153

# %%
labels = np.unique(y_pred)
sns.heatmap(confusion_matrix(y_test_proc, y_pred), annot=True, xticklabels=labels, yticklabels=labels, cmap="coolwarm")
plt.show()

# %% [markdown]
# That's it. After doing hyperparameter tuning, we got the best value for criterion is 'gini' and n_estimators is 50. With that parameter value, the accuracy of the resulting model increased by almost 1% to the test data. Although it's not much, but still there is an improvement from the resulting model.

# %% [markdown]
# # Evaluation

# %%
sample_data = pd.DataFrame({
    'Age': [30],
    'SystolicBP': [120],
    'DiastolicBP': [80],
    'BS': [7.0],
    'BodyTemp': [98.6]
})

predicted_risk = grid.predict(sample_data)

sample_data['PredictedRiskLevel'] = predicted_risk
display(sample_data)
# Out:
#    Age  SystolicBP  DiastolicBP   BS  BodyTemp PredictedRiskLevel
# 0   30         120           80  7.0      98.6           mid risk

# %%
import pickle

# Save the trained model (after hyperparameter tuning)
with open('maternal_health_model.pkl', 'wb') as f:
    pickle.dump(grid, f)
